# %% [markdown]
# # [IDEA 제공한 사이트](https://medium.com/jungle-book/towards-data-set-augmentation-with-gans-9dd64e9628e6)
#
# # Modification
# * [google wasserstein dist 추가](https://github.com/google/wasserstein-dist/blob/master/train.py)
# * variable_scope 추가
# * 수정한 Loss 방식 문제 확인 후 다시 원래대로
# * tf.nn.moments 를 활용하여 평균, 분산 구해서 통계량값이 맞도록 처리
# * dist 시각화 및 total dist를 잴 때 생성된 값과 여러번의 샘플링 된 것과의 거리들의 평균과 표준편차를 시각화
#     * cross validation 처럼 하고 싶었음.
#     * 평균도 낮으면서(분포간 거리도 가까우면서), 다양한 샘플을 넣었을 때도 거리차이가 작기를 기대하면서

# %%
import numpy as np
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import datasets , sys
from sklearn.preprocessing import MinMaxScaler
sys.path.append('/home/advice/Python/SR/Custom/')
from jupyter_tensorboard import *
from utility import *
from Init import *
from wasserstein import Wasserstein
from IPython.display import clear_output
churn = pd.read_csv("./../Data/Churn.csv")
# Out:
#     사용하면 좋은 패키지
#     train_validation_test_split / cat2dict / code2cat / colorlist / onehotencoding / roccurve  / ProbDensity
#     pycm import *
#     ConfusionMatrix(actual_vector=``test_y``, predict_vector= ``pred`` )
#     사용하면 통계량값 다 얻을 수 있음

# %%
churn.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
# 2             41.38  ...              110             10.30
# 3             50.90  ...               88              5.26
# 4             28.34  ...              122             12.61
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    customer service calls  churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False
#
# [5 rows x 21 columns]

# %%
churn.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %%
Real = churn[["state", "international plan" , 'total day charge' , 'total eve charge' ,  'total intl calls','total night calls' ,  'total day calls' , 'churn' , 'area code']]

# %% [markdown]
# https://stackoverflow.com/questions/21271581/selecting-pandas-columns-by-dtype
#
# ```
# ## all float
# df.select_dtypes(include=['floating'])
# ## all integer
# df.select_dtypes(include=['integer'])
# ## all numeric
# df.select_dtypes(include=['number'])
# ## select
# [col for col in df.columns.tolist() if df[col].dtype not in ['object','<M8[ns]']]
# ```

# %%
Real.dtypes
# Out:
# state                  object
# international plan     object
# total day charge      float64
# total eve charge      float64
# total intl calls        int64
# total night calls       int64
# total day calls         int64
# churn                    bool
# area code               int64
# dtype: object

# %% [markdown]
# ## PostProcessing
#
#
# * Numeric
#     * Inverse Transform을 진행해서 원래 분포의 범위로 변환시켜주기
#     * **integer**
#         * count variable 같은 경우 round로 정수형으로 처리해주기?
#     * **numeric**
#         * 그대로 사용해도 가능 할 듯
# * Categorical
#     * softmax로 나오므로 argmax 처리하고, 분포를 보여줄때는 수치형으로 보여주고 사용할 때는 변환하는 방식
#     * 일단 그림을 그릴 때는 그대로 사용하면 될 듯

# %%
Int_name = Real.select_dtypes(include= ["integer"]).columns.tolist()
object_name = Real.select_dtypes(exclude= ["number"]).columns.tolist()
numeric_name = Real.select_dtypes(include= ["number"]).columns.tolist()

object_name.append("area code")
numeric_name.remove("area code")
Int_name = list(set(Int_name) - set(object_name))
print("NUMERIC : " ,numeric_name)
print("OBJECT : ", object_name)
print("Int : ",Int_name)
# Out:
# NUMERIC :  ['total day charge', 'total eve charge', 'total intl calls', 'total night calls', 'total day calls']
# OBJECT :  ['state', 'international plan', 'churn', 'area code']
# Int :  ['total intl calls', 'total night calls', 'total day calls']

# %%
Real = Real[numeric_name + object_name ]

# %%
feature = Real.columns.tolist()

# %%
total_length = 0 
info = {}
for i in object_name :
    value = Real[i].nunique()
    info[i] = value
    total_length += value
    
total_length += len(numeric_name)
print(total_length)
print(info)
# Out:
# 63
# {'state': 51, 'international plan': 2, 'churn': 2, 'area code': 3}

# %%
info.get("state")
# Out:
# 51

# %%
data = Real.values
def sample_data(n= len(data) , data = None) : 
    output = data[list(np.random.choice(len(data) , n))]
    return output

# %%
input_dim = np.shape(data)[1] 
latet_dim = 20
BATCH_SIZE = 50
def generator(Z , batch_size , hsize=[ 50, 80 , 100],reuse=False):
    with tf.variable_scope("GAN/Generator",reuse=reuse):
        h1 = tf.layers.dense(Z,hsize[0],activation=None)
        h2 = tf.layers.dense(h1,hsize[1],activation=tf.nn.leaky_relu)
        h2 = tf.layers.dense(h1,hsize[1],activation=None) 
        h2 = tf.layers.dense(h2, hsize[2] , activation = tf.nn.leaky_relu , use_bias=True )  
        #num = tf.slice(h2 , [0,0] , [BATCH_SIZE, 22] )  # 
        #cat = tf.slice(h2 , [0,22] , [BATCH_SIZE, 3] ) # 
        out = tf.layers.dense(h2,  total_length , activation = None , use_bias= True )
        num = tf.slice(out , [0,0] , [batch_size,  len(numeric_name) ] )  # 
        first = tf_sqnl(num)
        ## Categorcial 
        NUM = 0
        for i in object_name :
            cat = tf.slice(out , [0,len(numeric_name) + NUM ] , [batch_size , info.get(i)] ) # 
            Species = tf.nn.softmax(cat)
            NUM += info.get(i)
            first = tf.concat([first , Species], axis = 1 , name = i[0] )
        #out = tf.layers.dense(num ,input_dim , activation = tf_sqnl , use_bias=False , name = 'Numerical' )  # activation=None 
    return first


def discriminator(X,hsize=[70, 40],reuse=True):
    with tf.variable_scope("GAN/Discriminator",reuse=reuse):
        h1 = tf.layers.dense(X,hsize[0],activation=tf.nn.leaky_relu , name = "D1")
        #h1 = minibatch(h1 , name = "D1")
        h2 = tf.layers.dense(h1,hsize[1],activation=tf.nn.leaky_relu , name = "D2" )
        h2 = minibatch(h2 , name = "D2")
        h3 = tf.layers.dense(h2,10 ,activation=tf.nn.leaky_relu , name = "D3" )
        #h3 = minibatch(h3 , name = "D3")
        out = tf.layers.dense(h3,1) # activation=None OUTPUT
    return out, h3

def sample_Z(m , n ):
    return np.random.uniform(-1., 1., size=[m , n])

# %%
input_dim
# Out:
# 9

# %%
tf.reset_default_graph()
BATCH_SIZE = 50
X = tf.placeholder(tf.float32,[None, total_length  ], name= "X")
Z = tf.placeholder(tf.float32,[None,latet_dim ] , name = "Z")
batch_size = tf.placeholder(tf.int64, name="Batchsize")

# %%
EPOCHS = 100000
BATCH_SIZE = 50
data_len = np.shape(data)[0]
batch_iter = int(data_len / BATCH_SIZE)

dataset = tf.data.Dataset.from_tensor_slices((X, Z)).batch(batch_size , drop_remainder=True ).repeat().shuffle(1000)
iter = dataset.make_initializable_iterator()
x , z = iter.get_next()

print(batch_iter)
# Out:
# WARNING:tensorflow:From /root/anaconda3/lib/python3.6/site-packages/tensorflow/python/data/ops/dataset_ops.py:1419: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 66

# %%
G_sample = generator(z , batch_size)
r_logits, r_rep = discriminator(x,reuse=False)
f_logits, g_rep = discriminator(G_sample,reuse=True)

# e = tf.random_uniform([BATCH_SIZE , 1] , 0 , 1)
# x_hat =  e * x + (1-e) * G_sample
# grad  = tf.gradients( discriminator(x_hat,reuse=True ), x_hat)[0]

#grad_norm = tf.norm( tf.layers.flatten(grad) , axis = 1)
#LP = 10 * tf.reduce_mean( tf.square( tf.maximum(0.0 ,grad_norm - 1.0)))


# slopes = tf.sqrt(1e-8 + tf.reduce_sum(tf.square(grad), axis=[1]))
# gradient_penalty = 5 * tf.reduce_mean((slopes - 1.) ** 2)
# Out:
# WARNING:tensorflow:From <ipython-input-12-27feefd7f3ee>:6: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.

# %%
# fake_logit = (f_logits - tf.reduce_mean(r_logits))
# real_logit = (r_logits - tf.reduce_mean(f_logits))
# real_logit = tf.sigmoid( real_logit )
# fake_logit = tf.sigmoid( fake_logit )
# disc_loss = - tf.reduce_mean( log(real_logit)) - tf.reduce_mean( log(1-fake_logit ))
# gen_loss = - tf.reduce_mean( log( fake_logit )) - tf.reduce_mean( log(1- real_logit ))


# disc_loss = tf.reduce_mean(
#     tf.nn.sigmoid_cross_entropy_with_logits(logits=r_logits,labels=tf.ones_like(r_logits)) + 
#     tf.nn.sigmoid_cross_entropy_with_logits(logits=f_logits,labels=tf.zeros_like(f_logits)) , name = "discriminator_loss")
# gen_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=f_logits,labels=tf.ones_like(f_logits)), name= "generator_loss")

## wgan Loss 변경
### 이유 : 이전에는 이미지다보니 2D 전체를 하는 것이 맞지만, 테이블 데이터 같은 경우에는 열별로 비교해야할듯하다.
### 이유2 : 전체적인 것도 고려할 수 있게하기! 
e = tf.random_uniform([BATCH_SIZE , 1] , 0 , 1)
x_hat =  e * x + (1-e) * G_sample
grad  = tf.gradients( discriminator(x_hat, reuse=True ), x_hat)[0]
slopes = tf.sqrt(1e-8 + tf.reduce_sum(tf.square(grad), axis=[1]))
gradient_penalty = 5 * tf.reduce_mean((slopes - 1.) ** 2)

fake_logit = (f_logits - tf.reduce_mean(r_logits))
real_logit = (r_logits - tf.reduce_mean(f_logits))
real_logit = tf.sigmoid( real_logit )
fake_logit = tf.sigmoid( fake_logit )

with tf.variable_scope("Discriminator_Loss") :        
#     total_disc_loss = tf.reduce_mean(f_logits) - tf.reduce_mean(r_logits)     
#     col_disc_loss = tf.reduce_sum(tf.reduce_mean(f_logits , axis = 0 ) - tf.reduce_mean(r_logits , axis = 0  ))
#     ratio = 1.0
#     disc_loss = ratio * total_disc_loss + (1-ratio) * col_disc_loss 
    disc_loss = - tf.reduce_mean( log(real_logit)) - tf.reduce_mean( log(1-fake_logit ))
    disc_loss += gradient_penalty

## 기존 wgan loss
#disc_loss = tf.reduce_mean(f_logits  ) - tf.reduce_mean(r_logits  ) + gradient_penalty
#gen_loss  = - tf.reduce_mean(f_logits)


## Numeric 변수에 대한 Correlation Loss 추가
### 이유는 상관관계가 유사하게 나와야 하기 때문에 규제를 주는 역할을 기대할 수 있다!
### Generator Loss에 넣어서 Generator에서만 Weight 조절할수 있게! 
def tf_cov(x):
    mean_x = tf.reduce_mean(x, axis=0, keep_dims=True)
    mx = tf.matmul(tf.transpose(mean_x), mean_x)
    vx = tf.matmul(tf.transpose(x), x)/tf.cast(tf.shape(x)[0], tf.float32)
    cov_xx = vx - mx
    return cov_xx

with tf.variable_scope("Generator_Loss"):
    with tf.variable_scope("Original_Loss"):
        gen_loss = - tf.reduce_mean( log( fake_logit )) - tf.reduce_mean( log(1- real_logit ))
        #gen_loss  = - tf.reduce_mean(f_logits)
        # -tf.reduce_sum(tf.reduce_mean(f_logits , axis = 0 ))
    with tf.variable_scope("Corr_Loss"):
        num_G = tf.slice(G_sample , [0,0] , [batch_size,  len(numeric_name) ] )  # 
        num_R = tf.slice(x , [0,0] , [batch_size,  len(numeric_name) ] )  # 
        corr_loss = tf.reduce_mean(tf.square( tf.div( tf_cov(num_G) - tf_cov(num_R) , 2 ) ))        
    tf.summary.scalar("corrloss", corr_loss)
    gen_loss += 5*corr_loss
    with tf.variable_scope("wasserstein_Loss"):
        wasserstein = Wasserstein(G_sample, x , BATCH_SIZE)
        loss = wasserstein.dist(C=0.1, nsteps=10)
    tf.summary.scalar("wasserstein_loss", loss)
    gen_loss += loss
    with tf.variable_scope("Stat"):
        Gcol_mean , Gcol_var = tf.nn.moments(G_sample , axes = [0])
        Xcol_mean , Xcol_var = tf.nn.moments(x , axes = [0])
        G_mean , G_var = tf.nn.moments(G_sample , axes = [0,1])
        X_mean , X_var = tf.nn.moments(x , axes = [0,1])
        Colstat = tf.reduce_mean(tf.square(Gcol_mean - Xcol_mean)) \
        + tf.reduce_mean(tf.square( tf.sqrt(Gcol_var) - tf.sqrt(Xcol_var)))
        Totalstat = tf.reduce_mean(tf.square(G_mean - X_mean)) \
        + tf.reduce_mean(tf.square( tf.sqrt(G_var) - tf.sqrt(X_var)))
    tf.summary.scalar("Colstat_Loss", Colstat)
    tf.summary.scalar("Totalstat_loss", Totalstat)
    #gen_loss += Colstat + Totalstat


tf.summary.scalar("Dloss", disc_loss)
tf.summary.scalar("Gloss", gen_loss)

t_vars = tf.trainable_variables()

for var in t_vars :
    tf.summary.histogram(var.op.name, var)

global_step = tf.get_variable('global_step', [], initializer=tf.constant_initializer(0), trainable=False)
gen_vars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES,scope="GAN/Generator")
disc_vars = tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES,scope="GAN/Discriminator")
lr = 0.001
learning_rate = tf.train.exponential_decay(lr, global_step, decay_steps=100, decay_rate=0.98, staircase=True , )

tf.summary.scalar("learning_rate", learning_rate)
with tf.variable_scope("Optimizer"):
    gen_step = tf.train.RMSPropOptimizer(learning_rate=learning_rate).minimize(gen_loss,var_list = gen_vars) # G Train step
    disc_step = tf.train.RMSPropOptimizer(learning_rate=learning_rate).minimize(disc_loss,var_list = disc_vars) # D Train step
# Out:
# WARNING:tensorflow:From /root/anaconda3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From <ipython-input-17-9c8f325df168>:59: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /home/advice/Python/SR/Custom/wasserstein.py:57: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
tensorboard()
# Out:
#         <iframe seamless style="width:100%;height:620px;border:0" srcdoc="
#         <script>
#         function load() {
#             document.getElementById(&quot;graph0.03240934233882853&quot;).pbtxt = 'node {\n  name: &quot;X&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: -1\n        }\n        dim {\n          size: 63\n        }\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Z&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_FLOAT\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        dim {\n          size: -1\n        }\n        dim {\n          size: 20\n        }\n      }\n    }\n  }\n}\nnode {\n  name: &quot;Batchsize&quot;\n  op: &quot;Placeholder&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT64\n    }\n  }\n  attr {\n    key: &quot;shape&quot;\n    value {\n      shape {\n        unknown_rank: true\n      }\n    }\n  }\n}\nnode {\n  name: &quot;drop_remainder&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_BOOL\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_BOOL\n        tensor_shape {\n        }\n        bool_val: true\n      }\n    }\n  }\n}\nnode {\n  name: &quot;count&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT64\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT64\n        tensor_shape {\n        }\n        int64_val: -1\n      }\n    }\n  }\n}\nnode {\n  name: &quot;buffer_size&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT64\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT64\n        tensor_shape {\n        }\n        int64_val: 1000\n      }\n    }\n  }\n}\nnode {\n  name: &quot;seed&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT64\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT64\n        tensor_shape {\n        }\n        int64_val: 0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;seed2&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_INT64\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_INT64\n        tensor_shape {\n        }\n        int64_val: 0\n      }\n    }\n  }\n}\nnode {\n  name: &quot;optimizations&quot;\n  op: &quot;Const&quot;\n  attr {\n    key: &quot;dtype&quot;\n    value {\n      type: DT_STRING\n    }\n  }\n  attr {\n    key: &quot;value&quot;\n    value {\n      tensor {\n        dtype: DT_STRING\n        tensor_shape {\n          dim {\n            size: 3\n          }\n        }\n        string_val: &quot;map_and_batch_fusion&quot;\n        string_val: &quot;noop_elimination&quot;\n        string_val: &quot;shuffle_and_repeat_fusion&quot;\n      }\n    }\n  }\n}\nnode {\n  name: &quot;IteratorV2&quot;\n  op: &quot;IteratorV2&quot;\n  attr {\n    key: &quot;container&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n  attr {\n    key: &quot;output_shapes&quot;\n    value {\n      list {\n        shape {\n          dim {\n            size: -1\n          }\n          dim {\n            size: 63\n          }\n        }\n        shape {\n          dim {\n            size: -1\n          }\n          dim {\n            size: 20\n          }\n        }\n      }\n    }\n  }\n  attr {\n    key: &quot;output_types&quot;\n    value {\n      list {\n        type: DT_FLOAT\n        type: DT_FLOAT\n      }\n    }\n  }\n  attr {\n    key: &quot;shared_name&quot;\n    value {\n      s: &quot;&quot;\n    }\n  }\n}\nnode {\n  name: &quot;TensorSliceDataset&quot;\n  op: &quot;TensorSliceDataset&quot;\n  input: &quot;X&q ...

# %%
config=tf.ConfigProto(log_device_placement=True)
config.gpu_options.allow_growth = True
merged_summary = tf.summary.merge_all()
sess = tf.Session(config= config)
saver = tf.train.Saver()

suumary_dir = "/home/advice/Python/SR/board/Gan_Chrun_Result"
try :
    if tf.gfile.Exists(suumary_dir):
        tf.gfile.DeleteRecursively(suumary_dir)
        tf.gfile.MakeDirs(suumary_dir)
        tf.gfile.DeleteRecursively("./gan_Chrun_result")
        tf.gfile.MakeDirs("./gan_Chrun_result")
except Exception as e :
    tf.gfile.MakeDirs("./gan_Chrun_result")
    
    
writer = tf.summary.FileWriter(suumary_dir)
writer.add_graph(sess.graph )
tf.global_variables_initializer().run(session=sess)

# %%
load_model = False
if load_model == True :
    print("학습된 모델 사용하기")
    save_file = "./savemodel/gan.meta"
    saver = tf.train.import_meta_graph(save_file)
    saver.restore(sess, tf.train.latest_checkpoint('./savemodel/'))
else :
    print("처음부터 학습시키기")
# Out:
# 처음부터 학습시키기

# %%
original = data.copy()
transform = original.copy()

# %%
from sklearn import preprocessing 
label_encoder = preprocessing.LabelEncoder()
onehot_encoder = preprocessing.OneHotEncoder(sparse=False)
##
TOTAL = data[:,:len(numeric_name)]
onehot_bin = []
for i in range(len(numeric_name) , np.shape(data)[1]) :
    label_encoder.fit(data[:,i])
    encoding = label_encoder.transform(data[:,i])
    onehot_encoder.fit(np.array(encoding).reshape(-1,1))
    cat = onehot_encoder.transform(np.array(encoding).reshape(-1,1))
    onehot_bin.append(TOTAL.shape[1])
    TOTAL = np.concatenate((TOTAL , cat) , axis = 1 )
    transform[:,i] = label_encoder.transform(transform[:,i])

data= TOTAL
del TOTAL
onehot_bin += [data.shape[1]]
print(onehot_bin)
# Out:
# [5, 56, 58, 60, 63]
# /root/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /root/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /root/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /root/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/_encoders.py:415: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
data.shape
# Out:
# (3333, 63)

# %%
x_plot = sample_data(n= 500 , data = transform ).astype(float) # len(data)
x_plot.shape
# Out:
# (500, 9)

# %%
# x_plot2 = x_plot[:,:len(numeric_name)].copy()
# for idx , i in enumerate(onehot_bin[:-1]) :
#     x_plot2 = np.concatenate( (x_plot2 ,
#                                np.argmax(x_plot[:, onehot_bin[idx] : onehot_bin[idx+1] ] , 1 )[:,np.newaxis] ) , axis = 1 )
# x_plot = x_plot2
# del x_plot2

# %%
from scipy.stats import wasserstein_distance as was_dist
nd_steps = 1
ng_steps = 1
save_model = True
scaler = MinMaxScaler(feature_range=(-1. ,1.))
## 표준화로 해보기!
#from sklearn.preprocessing import StandardScaler
#scaler = StandardScaler()
data[:,:len(numeric_name)] = scaler.fit_transform(data[:,:len(numeric_name)])

# %%
data.shape
# Out:
# (3333, 63)

# %%
x_plot.shape
# Out:
# (500, 9)

# %%
def main() :
    imgs = []
    Total_ws = pd.DataFrame({"iter":[0] , "ws" :[0], "wstd" : [0]})
    for i in range(EPOCHS) : 
        z_batch = sample_Z(data_len , latet_dim )
        sess.run(iter.initializer, feed_dict={ X : data , 
                                              batch_size: BATCH_SIZE , 
                                              Z : z_batch  ,
                                             })
        #for _ in range( batch_iter)  :
        nd_steps = 2
        for _ in range(nd_steps):
            _, dloss  = sess.run([disc_step, disc_loss] , feed_dict={global_step : i ,
                                                                     batch_size : BATCH_SIZE
                                                                    })
        #writer.add_summary(summary, global_step=i)
        for _ in range(ng_steps):
            _, gloss = sess.run([gen_step, gen_loss], feed_dict={global_step : i , 
                                                                 batch_size : BATCH_SIZE
                                                                })
        #writer.add_summary(summary, global_step = i)

        if i% 100 == 0 :
            try :
                _ , _ , _ , _ , summary_str = sess.run([disc_step , gen_step , disc_loss , gen_loss , merged_summary] , 
                                                       feed_dict = {global_step : i ,
                                                                    batch_size : BATCH_SIZE
                                                                   })
                writer.add_summary(summary_str , global_step = i)
            except Exception as e :
                pass 

            if save_model == True :
                saver.save(sess, './savemodel/gan')
            clear_output(wait= True)
            generate_n = 500
            z_batch = sample_Z(generate_n  , latet_dim )
            g_plot = sess.run(G_sample , feed_dict = {z : z_batch , batch_size : generate_n})
            g_plot[:,:len(numeric_name)] = scaler.inverse_transform(g_plot[:,:len(numeric_name)])
            g_numeric = g_plot[:,:len(numeric_name)]
            for idx , _ in enumerate(onehot_bin[:-1]) :
                cat = np.argmax(g_plot[:, onehot_bin[idx] : onehot_bin[idx+1] ], 1 )
                g_numeric = np.concatenate((g_numeric ,cat[:,np.newaxis] ) , axis = 1 )
            g_plot = g_numeric
            del g_numeric
            print(np.array(g_plot).shape)
            fig, ax = plt.subplots(3,3, figsize=(14, 10))
            axx = ax.flatten()
            num = 0
            total_dist = 0 
            for n , name in enumerate(feature) :
                try :
                    total_dist += was_dist(x_plot[:,n], g_plot[:,n])
                except Exception as e :
                    pass
                
                if name in ['international plan', 'churn', 'area code' , "state"]  :
                    print(name)
                    print("gene -----------")
                    print(np.bincount( np.array(g_plot[:,n]).astype(int) ) )
                    print("true -----------")
                    print(np.bincount( np.array(x_plot[:,n]).astype(int) ) )
                    print("-----------------")
                    
                if name in ['international plan', 'churn', 'area code']  :
                    sns.distplot(x_plot[:,n].astype(float) , kde = False ,  
                                 hist_kws ={"color":"r", "label" : "Real"} ,  
                                 rug = True , ax = axx[num])
                    sns.distplot(g_plot[:,n],  kde = False ,  
                                 hist_kws ={"color":"g" , "label" : "Gene"} ,
                                 rug = True   , ax = axx[num])
                else :
                    if name in Int_name : 
                        Real  = x_plot[:,n].astype(float).round(0)
                        Fake  = g_plot[:,n].round(0)
                    else :
                        Real  = x_plot[:,n].astype(float)
                        Fake  = g_plot[:,n]
                    sns.distplot(Real  , kde_kws ={"color": "r", "label" : "Real"} , hist_kws ={"color":"r"}, ax = axx[num])
                    sns.distplot(Fake , kde_kws ={"color": "g", "label" : "Gene"} , hist_kws ={"color":"g"}, ax = axx[num])
                axx[num].set_title("{}".format(name))
                num +=1
            plt.suptitle('Iteration %d , D_loss : %.4f , G_loss : %.4f , Dist : %.4f'%(i,dloss,gloss, total_dist) )
            plt.savefig('./gan_Chrun_result/iteration_%d.png'%i)
            imgs.append('./gan_Chrun_result/iteration_%d.png'%i)
            ## 쓸모없는 것 제거 
            plt.show()
            total_dist = []
            for _ in range(10) :
                sampling = sample_data(n= 500 , data = transform).astype(float) # len(data)
                dist = 0
                for col in range(len(feature)) :
                    try :
                        dist += was_dist(sampling[:,col], g_plot[:,col])
                    except Exception as e :
                        pass
                total_dist.append(dist)
            total_std = np.std(total_dist)
            total_dist = np.mean(total_dist)
            iter_ws = pd.DataFrame({"iter":[i] , "ws" :[total_dist] , "wstd" : [total_std]})
            Total_ws    = Total_ws.append(iter_ws)
            fig , ax = plt.subplots(figsize = (26,13))
            fig.subplots_adjust(top = 0.95 , left = 0.03 , bottom = 0.04 , right = 0.99)
            Total_ws = Total_ws[Total_ws.iter > 0 ]
            ax.plot(Total_ws["iter"] , Total_ws["ws"] , linestyle ="-" , marker ="." , linewidth = 3, markersize = 12)
            ax.plot(Total_ws["iter"] , Total_ws["ws"]-1.96*Total_ws["wstd"] , linestyle ="dashed" , marker ="." , linewidth = 1, markersize = 12)
            ax.plot(Total_ws["iter"] , Total_ws["ws"]+1.96*Total_ws["wstd"] , linestyle ="dashed" , marker ="." , linewidth = 1, markersize = 12)
            ax.set_title("EPOCH : {} , WS : {:.3f}[{:.3f}]".format(i , total_dist , Total_ws.ws.min()) , fontsize = 30)
            plt.savefig('./Churn_Iter_Dist.png')
            plt.show()
    return imgs

# %%
if __name__ == "__main__" :
    imgs = main()
# Out:
# (500, 9)
# /root/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# state
# gene -----------
# [ 0 17 12 27  0 35  9  0  0  0  2  6  7 12  6 16  3  8 12 14 14  8  7 11
#   4  5  5  0  0  4  7 18  5 17 21 12  4  0  4  5  4  0 10 86  3 17  7 14
#  12  0 10]
# true -----------
# [ 6 15  8  9  5  8  9 10 12  9 12  7  9 18  5 12  6  3  6 11 14  8 15 11
#  11 11 14 11  9 14  9 10  7 11 10 13 11 10  4  8  3  9 10 15  7  5 12 14
#   9 20  5]
# -----------------
# international plan
# gene -----------
# [459  41]
# true -----------
# [442  58]
# -----------------
# churn
# gene -----------
# [431  69]
# true -----------
# [427  73]
# -----------------
# area code
# gene -----------
# [142 227 131]
# true -----------
# [135 247 118]
# -----------------

# %%
imgs
# Out:
# ['./gan_Chrun_result/iteration_0.png',
#  './gan_Chrun_result/iteration_100.png',
#  './gan_Chrun_result/iteration_200.png',
#  './gan_Chrun_result/iteration_300.png',
#  './gan_Chrun_result/iteration_400.png',
#  './gan_Chrun_result/iteration_500.png',
#  './gan_Chrun_result/iteration_600.png',
#  './gan_Chrun_result/iteration_700.png',
#  './gan_Chrun_result/iteration_800.png',
#  './gan_Chrun_result/iteration_900.png',
#  './gan_Chrun_result/iteration_1000.png',
#  './gan_Chrun_result/iteration_1100.png',
#  './gan_Chrun_result/iteration_1200.png',
#  './gan_Chrun_result/iteration_1300.png',
#  './gan_Chrun_result/iteration_1400.png',
#  './gan_Chrun_result/iteration_1500.png',
#  './gan_Chrun_result/iteration_1600.png',
#  './gan_Chrun_result/iteration_1700.png',
#  './gan_Chrun_result/iteration_1800.png',
#  './gan_Chrun_result/iteration_1900.png',
#  './gan_Chrun_result/iteration_2000.png',
#  './gan_Chrun_result/iteration_2100.png',
#  './gan_Chrun_result/iteration_2200.png',
#  './gan_Chrun_result/iteration_2300.png',
#  './gan_Chrun_result/iteration_2400.png',
#  './gan_Chrun_result/iteration_2500.png',
#  './gan_Chrun_result/iteration_2600.png',
#  './gan_Chrun_result/iteration_2700.png',
#  './gan_Chrun_result/iteration_2800.png',
#  './gan_Chrun_result/iteration_2900.png',
#  './gan_Chrun_result/iteration_3000.png',
#  './gan_Chrun_result/iteration_3100.png',
#  './gan_Chrun_result/iteration_3200.png',
#  './gan_Chrun_result/iteration_3300.png',
#  './gan_Chrun_result/iteration_3400.png',
#  './gan_Chrun_result/iteration_3500.png',
#  './gan_Chrun_result/iteration_3600.png',
#  './gan_Chrun_result/iteration_3700.png',
#  './gan_Chrun_result/iteration_3800.png',
#  './gan_Chrun_result/iteration_3900.png',
#  './gan_Chrun_result/iteration_4000.png',
#  './gan_Chrun_result/iteration_4100.png',
#  './gan_Chrun_result/iteration_4200.png',
#  './gan_Chrun_result/iteration_4300.png',
#  './gan_Chrun_result/iteration_4400.png',
#  './gan_Chrun_result/iteration_4500.png',
#  './gan_Chrun_result/iteration_4600.png',
#  './gan_Chrun_result/iteration_38100.png',
#  './gan_Chrun_result/iteration_38200.png',
#  './gan_Chrun_result/iteration_38300.png',
#  './gan_Chrun_result/iteration_38400.png',
#  './gan_Chrun_result/iteration_38500.png',
#  './gan_Chrun_result/iteration_38600.png',
#  './gan_Chrun_result/iteration_38700.png',
#  './gan_Chrun_result/iteration_38800.png',
#  './gan_Chrun_result/iteration_38900.png',
#  './gan_Chrun_result/iteration_39000.png',
#  './gan_Chrun_result/iteration_39100.png',
#  './gan_Chrun_result/iteration_39200.png',
#  './gan_Chrun_result/iteration_39300.png',
#  './gan_Chrun_result/iteration_39400.png',
#  './gan_Chrun_result/iteration_39500.png',
#  './gan_Chrun_result/iteration_39600.png',
#  './gan_Chrun_result/iteration_39700.png',
#  './gan_Chrun_result/iteration_39800.png',
#  './gan_Chrun_result/iteration_39900.png',
#  './gan_Chrun_result/iteration_40000.png',
#  './gan_Chrun_result/iteration_40100.png',
#  './gan_Chrun_result/iteration_40200.png',
#  './gan_Chrun_result/iteration_40300.png',
#  './gan_Chrun_result/iteration_40400.png',
#  './gan_Chrun_result/iteration_40500.png',
#  './gan_Chrun_result/iteration_40600.png',
#  './gan_Chrun_result/iteration_40700.png',
#  './gan_Chrun_result/iteration_40800.png',
#  './gan_Chrun_result/iteration_40900.png',
#  './gan_Chrun_result/iteration_41000.png',
#  './gan_Chrun_result/iteration_41100.png',
#  './gan_Chrun_result/iteration_41200.png',
#  './gan_Chrun_result/iteration_41300.png',
#  './gan_Chrun_result/iteration_41400.png',
#  './gan_Chrun_result/iteration_41500.png',
#  './gan_Chrun_result/iteration_41600.png',
#  './gan_Chrun_result/iteration_41700.png',
#  './gan_Chrun_result/iteration_41800.png',
#  './gan_Chrun_result/iteration_41900.png',
#  './gan_Chrun_result/iteration_42000.png',
#  './gan_Chrun_result/iteration_42100.png',
#  './gan_Chrun_result/iteration_42200.png',
#  './gan_Chrun_result/iteration_42300.png',
#  './gan_Chrun_result/iteration_42400.png',
#  './gan_Chrun_result/iteration_42500.png',
#  './gan_Chrun_result/iteration_42600.png',
#  './gan_Chrun_result/iteration_42700.png',
#  './gan_Chrun_result/iteration_42800.png',
#  './gan_Chrun_result/iteration_42900.png',
#  './gan_Chrun_result/iteration_43000.png',
#  './gan_Chrun_result/iteration_43100.png',
#  './gan_Chrun_result/iteration_43200.png',
#  './gan_Chrun_result/iteration_43300.png',
#  './gan_Chrun_result/iteration_43400.png',
#  './gan_Chrun_result/iteration_43500.png',
#  './gan_Chrun_result/iteration_43600.png',
#  './gan_Chrun_result/iteration_43700.png',
#  './gan_Chrun_result/iteration_43800.png',
#  './gan_Chrun_result/iteration_43900.png',
#  './gan_Chrun_result/iteration_44000.png',
#  './gan_Chrun_result/iteration_44100.png',
#  './gan_Chrun_result/iteration_44200.png',
#  './gan_Chrun_result/iteration_44300.png',
#  './gan_Chrun_result/iteration_44400.png',
#  './gan_Chrun_result/iteration_44500.png',
#  './gan_Chrun_result/iteration_44600.png',
#  './gan_Chrun_result/iteration_44700.png',
#  './gan_Chrun_result/iteration_58100.png',
#  './gan_Chrun_result/iteration_58200.png',
#  './gan_Chrun_result/iteration_58300.png',
#  './gan_Chrun_result/iteration_58400.png',
#  './gan_Chrun_result/iteration_58500.png',
#  './gan_Chrun_result/iteration_58600.png',
#  './gan_Chrun_result/iteration_58700.png',
#  './gan_Chrun_result/iteration_58800.png',
#  './gan_Chrun_result/iteration_58900.png',
#  './gan_Chrun_result/iteration_59000.png',
#  './gan_Chrun_result/iteration_59100.png',
#  './gan_Chrun_result/iteration_59200.png',
#  './gan_Chrun_result/iteration_59300.png',
#  './gan_Chrun_result/iteration_59400.png',
#  './gan_Chrun_result/iteration_59500.png',
#  './gan_Chrun_result/iteration_59600.png',
#  './gan_Chrun_result/iteration_59700.png',
#  './gan_Chrun_result/iteration_59800.png',
#  './gan_Chrun_result/iteration_59900.png',
#  './gan_Chrun_result/iteration_60000.png',
#  './gan_Chrun_result/iteration_60100.png',
#  './gan_Chrun_result/iteration_60200.png',
#  './gan_Chrun_result/iteration_60300.png',
#  './gan_Chrun_result/iteration_60400.png',
#  './gan_Chrun_result/iteration_60500.png',
#  './gan_Chrun_result/iteration_60600.png',
#  './gan_Chrun_result/iteration_60700.png',
#  './gan_Chrun_result/iteration_60800.png',
#  './gan_Chrun_result/iteration_60900.png',
#  './gan_Chrun_result/iteration_61000.png',
#  './gan_Chrun_result/iteration_61100.png',
#  './gan_Chrun_result/iteration_61200.png',
#  './gan_Chrun_result/iteration_61300.png',
#  './gan_Chrun_result/iteration_61400.png',
#  './gan_Chrun_result/iteration_61500.png',
#  './gan_Chrun_result/iteration_61600.png',
#  './gan_Chrun_result/iteration_61700.png',
#  './gan_Chrun_result/iteration_61800.png',
#  './gan_Chrun_result/iteration_61900.png',
#  './gan_Chrun_result/iteration_62000.png',
#  './gan_Chrun_result/iteration_62100.png',
#  './gan_Chrun_result/iteration_62200.png',
#  './gan_Chrun_result/iteration_62300.png',
#  './gan_Chrun_result/iteration_62400.png',
#  './gan_Chrun_result/iteration_62500.png',
#  './gan_Chrun_result/iteration_62600.png',
#  './gan_Chrun_result/iteration_62700.png',
#  './gan_Chrun_result/iteration_62800.png',
#  './gan_Chrun_result/iteration_62900.png',
#  './gan_Chrun_result/iteration_63000.png',
#  './gan_Chrun_result/iteration_63100.png',
#  './gan_Chrun_result/iteration_63200.png',
#  './gan_Chrun_result/iteration_63300.png',
#  './gan_Chrun_result/iteration_63400.png',
#  './gan_Chrun_result/iteration_63500.png',
#  './gan_Chrun_result/iteration_63600.png',
#  './gan_Chrun_result/iteration_63700.png',
#  './gan_Chrun_result/iteration_63800.png',
#  './gan_Chrun_result/iteration_63900.png',
#  './gan_Chrun_result/iteration_64000.png',
#  './gan_Chrun_result/iteration_64100.png',
#  './gan_Chrun_result/iteration_64200.png',
#  './gan_Chrun_result/iteration_64300.png',
#  './gan_Chrun_result/iteration_64400.png',
#  './gan_Chrun_result/iteration_64500.png',
#  './gan_Chrun_result/iteration_64600.png',
#  './gan_Chrun_result/iteration_64700.png',
#  './gan_Chrun_result/iteration_64800.png',
#  './gan_Chrun_result/iteration_64900.png',
#  './gan_Chrun_result/iteration_65000.png',
#  './gan_Chrun_result/iteration_65100.png',
#  './gan_Chrun_result/iteration_65200.png',
#  './gan_Chrun_result/iteration_65300.png',
#  './gan_Chrun_result/iteration_65400.png',
#  './gan_Chrun_result/iteration_65500.png',
#  './gan_Chrun_result/iteration_65600.png',
#  './gan_Chrun_result/iteration_65700.png',
#  './gan_Chrun_result/iteration_65800.png',
#  './gan_Chrun_result/iteration_65900.png',
#  './gan_Chrun_result/iteration_66000.png',
#  './gan_Chrun_result/iteration_66100.png',
#  './gan_Chrun_result/iteration_66200.png',
#  './gan_Chrun_result/iteration_66300.png',
#  './gan_Chrun_result/iteration_66400.png',
#  './gan_Chrun_result/iteration_66500.png',
#  './gan_Chrun_result/iteration_66600.png',
#  './gan_Chrun_result/iteration_66700.png',
#  './gan_Chrun_result/iteration_66800.png',
#  './gan_Chrun_result/iteration_66900.png',
#  './gan_Chrun_result/iteration_67000.png',
#  './gan_Chrun_result/iteration_67100.png',
#  './gan_Chrun_result/iteration_67200.png',
#  './gan_Chrun_result/iteration_67300.png',
#  './gan_Chrun_result/iteration_67400.png',
#  './gan_Chrun_result/iteration_67500.png',
#  './gan_Chrun_result/iteration_67600.png',
#  './gan_Chrun_result/iteration_67700.png',
#  './gan_Chrun_result/iteration_67800.png',
#  './gan_Chrun_result/iteration_67900.png',
#  './gan_Chrun_result/iteration_68000.png',
#  './gan_Chrun_result/iteration_68100.png',
#  './gan_Chrun_result/iteration_68200.png',
#  './gan_Chrun_result/iteration_68300.png',
#  './gan_Chrun_result/iteration_68400.png',
#  './gan_Chrun_result/iteration_68500.png',
#  './gan_Chrun_result/iteration_68600.png',
#  './gan_Chrun_result/iteration_68700.png',
#  './gan_Chrun_result/iteration_68800.png',
#  './gan_Chrun_result/iteration_68900.png',
#  './gan_Chrun_result/iteration_69000.png',
#  './gan_Chrun_result/iteration_69100.png',
#  './gan_Chrun_result/iteration_69200.png',
#  './gan_Chrun_result/iteration_69300.png',
#  './gan_Chrun_result/iteration_69400.png',
#  './gan_Chrun_result/iteration_69500.png',
#  './gan_Chrun_result/iteration_69600.png',
#  './gan_Chrun_result/iteration_69700.png',
#  './gan_Chrun_result/iteration_69800.png',
#  './gan_Chrun_result/iteration_69900.png',
#  './gan_Chrun_result/iteration_70000.png',
#  './gan_Chrun_result/iteration_70100.png',
#  './gan_Chrun_result/iteration_70200.png',
#  './gan_Chrun_result/iteration_70300.png',
#  './gan_Chrun_result/iteration_70400.png',
#  './gan_Chrun_result/iteration_70500.png',
#  './gan_Chrun_result/iteration_70600.png',
#  './gan_Chrun_result/iteration_70700.png',
#  './gan_Chrun_result/iteration_70800.png',
#  './gan_Chrun_result/iteration_70900.png',
#  './gan_Chrun_result/iteration_71000.png',
#  './gan_Chrun_result/iteration_71100.png',
#  './gan_Chrun_result/iteration_71200.png',
#  './gan_Chrun_result/iteration_71300.png',
#  './gan_Chrun_result/iteration_71400.png',
#  './gan_Chrun_result/iteration_71500.png',
#  './gan_Chrun_result/iteration_71600.png',
#  './gan_Chrun_result/iteration_71700.png',
#  './gan_Chrun_result/iteration_71800.png',
#  './gan_Chrun_result/iteration_71900.png',
#  './gan_Chrun_result/iteration_72000.png',
#  './gan_Chrun_result/iteration_72100.png',
#  './gan_Chrun_result/iteration_72200.png',
#  './gan_Chrun_result/iteration_72300.png',
#  './gan_Chrun_result/iteration_72400.png',
#  './gan_Chrun_result/iteration_72500.png',
#  './gan_Chrun_result/iteration_72600.png',
#  './gan_Chrun_result/iteration_72700.png',
#  './gan_Chrun_result/iteration_72800.png',
#  './gan_Chrun_result/iteration_72900.png',
#  './gan_Chrun_result/iteration_73000.png',
#  './gan_Chrun_result/iteration_73100.png',
#  './gan_Chrun_result/iteration_73200.png',
#  './gan_Chrun_result/iteration_73300.png',
#  './gan_Chrun_result/iteration_73400.png',
#  './gan_Chrun_result/iteration_73500.png',
#  './gan_Chrun_result/iteration_73600.png',
#  './gan_Chrun_result/iteration_73700.png',
#  './gan_Chrun_result/iteration_73800.png',
#  './gan_Chrun_result/iteration_73900.png',
#  './gan_Chrun_result/iteration_74000.png',
#  './gan_Chrun_result/iteration_74100.png',
#  './gan_Chrun_result/iteration_74200.png',
#  './gan_Chrun_result/iteration_74300.png',
#  './gan_Chrun_result/iteration_74400.png',
#  './gan_Chrun_result/iteration_74500.png',
#  './gan_Chrun_result/iteration_74600.png',
#  './gan_Chrun_result/iteration_74700.png',
#  './gan_Chrun_result/iteration_74800.png',
#  './gan_Chrun_result/iteration_74900.png',
#  './gan_Chrun_result/iteration_75000.png',
#  './gan_Chrun_result/iteration_75100.png',
#  './gan_Chrun_result/iteration_75200.png',
#  './gan_Chrun_result/iteration_75300.png',
#  './gan_Chrun_result/iteration_75400.png',
#  './gan_Chrun_result/iteration_75500.png',
#  './gan_Chrun_result/iteration_75600.png',
#  './gan_Chrun_result/iteration_75700.png',
#  './gan_Chrun_result/iteration_75800.png',
#  './gan_Chrun_result/iteration_75900.png',
#  './gan_Chrun_result/iteration_76000.png',
#  './gan_Chrun_result/iteration_76100.png',
#  './gan_Chrun_result/iteration_76200.png',
#  './gan_Chrun_result/iteration_76300.png',
#  './gan_Chrun_result/iteration_76400.png',
#  './gan_Chrun_result/iteration_76500.png',
#  './gan_Chrun_result/iteration_76600.png',
#  './gan_Chrun_result/iteration_76700.png',
#  './gan_Chrun_result/iteration_76800.png',
#  './gan_Chrun_result/iteration_76900.png',
#  './gan_Chrun_result/iteration_77000.png',
#  './gan_Chrun_result/iteration_77100.png',
#  './gan_Chrun_result/iteration_77200.png',
#  './gan_Chrun_result/iteration_77300.png',
#  './gan_Chrun_result/iteration_77400.png',
#  './gan_Chrun_result/iteration_77500.png',
#  './gan_Chrun_result/iteration_77600.png',
#  './gan_Chrun_result/iteration_77700.png',
#  './gan_Chrun_result/iteration_77800.png',
#  './gan_Chrun_result/iteration_77900.png',
#  './gan_Chrun_result/iteration_78000.png',
#  './gan_Chrun_result/iteration_78100.png',
#  './gan_Chrun_result/iteration_78200.png',
#  './gan_Chrun_result/iteration_78300.png',
#  './gan_Chrun_result/iteration_78400.png',
#  './gan_Chrun_result/iteration_78500.png',
#  './gan_Chrun_result/iteration_78600.png',
#  './gan_Chrun_result/iteration_78700.png',
#  './gan_Chrun_result/iteration_78800.png',
#  './gan_Chrun_result/iteration_78900.png',
#  './gan_Chrun_result/iteration_79000.png',
#  './gan_Chrun_result/iteration_79100.png',
#  './gan_Chrun_result/iteration_79200.png',
#  './gan_Chrun_result/iteration_79300.png',
#  './gan_Chrun_result/iteration_79400.png',
#  './gan_Chrun_result/iteration_79500.png',
#  './gan_Chrun_result/iteration_79600.png',
#  './gan_Chrun_result/iteration_79700.png',
#  './gan_Chrun_result/iteration_79800.png',
#  './gan_Chrun_result/iteration_79900.png',
#  './gan_Chrun_result/iteration_80000.png',
#  './gan_Chrun_result/iteration_80100.png',
#  './gan_Chrun_result/iteration_80200.png',
#  './gan_Chrun_result/iteration_80300.png',
#  './gan_Chrun_result/iteration_80400.png',
#  './gan_Chrun_result/iteration_80500.png',
#  './gan_Chrun_result/iteration_80600.png',
#  './gan_Chrun_result/iteration_80700.png',
#  './gan_Chrun_result/iteration_80800.png',
#  './gan_Chrun_result/iteration_80900.png',
#  './gan_Chrun_result/iteration_81000.png',
#  './gan_Chrun_result/iteration_81100.png',
#  './gan_Chrun_result/iteration_81200.png',
#  './gan_Chrun_result/iteration_81300.png',
#  './gan_Chrun_result/iteration_81400.png',
#  './gan_Chrun_result/iteration_81500.png',
#  './gan_Chrun_result/iteration_81600.png',
#  './gan_Chrun_result/iteration_81700.png',
#  './gan_Chrun_result/iteration_81800.png',
#  './gan_Chrun_result/iteration_81900.png',
#  './gan_Chrun_result/iteration_82000.png',
#  './gan_Chrun_result/iteration_82100.png',
#  './gan_Chrun_result/iteration_82200.png',
#  './gan_Chrun_result/iteration_82300.png',
#  './gan_Chrun_result/iteration_82400.png',
#  './gan_Chrun_result/iteration_82500.png',
#  './gan_Chrun_result/iteration_82600.png',
#  './gan_Chrun_result/iteration_82700.png',
#  './gan_Chrun_result/iteration_82800.png',
#  './gan_Chrun_result/iteration_82900.png',
#  './gan_Chrun_result/iteration_83000.png',
#  './gan_Chrun_result/iteration_83100.png',
#  './gan_Chrun_result/iteration_83200.png',
#  './gan_Chrun_result/iteration_83300.png',
#  './gan_Chrun_result/iteration_83400.png',
#  './gan_Chrun_result/iteration_83500.png',
#  './gan_Chrun_result/iteration_83600.png',
#  './gan_Chrun_result/iteration_83700.png',
#  './gan_Chrun_result/iteration_83800.png',
#  './gan_Chrun_result/iteration_83900.png',
#  './gan_Chrun_result/iteration_84000.png',
#  './gan_Chrun_result/iteration_84100.png',
#  './gan_Chrun_result/iteration_84200.png',
#  './gan_Chrun_result/iteration_84300.png',
#  './gan_Chrun_result/iteration_84400.png',
#  './gan_Chrun_result/iteration_84500.png',
#  './gan_Chrun_result/iteration_84600.png',
#  './gan_Chrun_result/iteration_84700.png',
#  './gan_Chrun_result/iteration_84800.png',
#  './gan_Chrun_result/iteration_84900.png',
#  './gan_Chrun_result/iteration_85000.png',
#  './gan_Chrun_result/iteration_85100.png',
#  './gan_Chrun_result/iteration_85200.png',
#  './gan_Chrun_result/iteration_85300.png',
#  './gan_Chrun_result/iteration_85400.png',
#  './gan_Chrun_result/iteration_85500.png',
#  './gan_Chrun_result/iteration_85600.png',
#  './gan_Chrun_result/iteration_85700.png',
#  './gan_Chrun_result/iteration_85800.png',
#  './gan_Chrun_result/iteration_85900.png',
#  './gan_Chrun_result/iteration_86000.png',
#  './gan_Chrun_result/iteration_86100.png',
#  './gan_Chrun_result/iteration_86200.png',
#  './gan_Chrun_result/iteration_86300.png',
#  './gan_Chrun_result/iteration_86400.png',
#  './gan_Chrun_result/iteration_86500.png',
#  './gan_Chrun_result/iteration_86600.png',
#  './gan_Chrun_result/iteration_86700.png',
#  './gan_Chrun_result/iteration_86800.png',
#  './gan_Chrun_result/iteration_86900.png',
#  './gan_Chrun_result/iteration_87000.png',
#  './gan_Chrun_result/iteration_87100.png',
#  './gan_Chrun_result/iteration_87200.png',
#  './gan_Chrun_result/iteration_87300.png',
#  './gan_Chrun_result/iteration_87400.png',
#  './gan_Chrun_result/iteration_87500.png',
#  './gan_Chrun_result/iteration_87600.png',
#  './gan_Chrun_result/iteration_87700.png',
#  './gan_Chrun_result/iteration_87800.png',
#  './gan_Chrun_result/iteration_87900.png',
#  './gan_Chrun_result/iteration_88000.png',
#  './gan_Chrun_result/iteration_88100.png',
#  './gan_Chrun_result/iteration_88200.png',
#  './gan_Chrun_result/iteration_88300.png',
#  './gan_Chrun_result/iteration_88400.png',
#  './gan_Chrun_result/iteration_88500.png',
#  './gan_Chrun_result/iteration_88600.png',
#  './gan_Chrun_result/iteration_88700.png',
#  './gan_Chrun_result/iteration_88800.png',
#  './gan_Chrun_result/iteration_88900.png',
#  './gan_Chrun_result/iteration_89000.png',
#  './gan_Chrun_result/iteration_89100.png',
#  './gan_Chrun_result/iteration_89200.png',
#  './gan_Chrun_result/iteration_89300.png',
#  './gan_Chrun_result/iteration_89400.png',
#  './gan_Chrun_result/iteration_89500.png',
#  './gan_Chrun_result/iteration_89600.png',
#  './gan_Chrun_result/iteration_89700.png',
#  './gan_Chrun_result/iteration_89800.png',
#  './gan_Chrun_result/iteration_89900.png',
#  './gan_Chrun_result/iteration_90000.png',
#  './gan_Chrun_result/iteration_90100.png',
#  './gan_Chrun_result/iteration_90200.png',
#  './gan_Chrun_result/iteration_90300.png',
#  './gan_Chrun_result/iteration_90400.png',
#  './gan_Chrun_result/iteration_90500.png',
#  './gan_Chrun_result/iteration_90600.png',
#  './gan_Chrun_result/iteration_90700.png',
#  './gan_Chrun_result/iteration_90800.png',
#  './gan_Chrun_result/iteration_90900.png',
#  './gan_Chrun_result/iteration_91000.png',
#  './gan_Chrun_result/iteration_91100.png',
#  './gan_Chrun_result/iteration_91200.png',
#  './gan_Chrun_result/iteration_91300.png',
#  './gan_Chrun_result/iteration_91400.png',
#  './gan_Chrun_result/iteration_91500.png',
#  './gan_Chrun_result/iteration_91600.png',
#  './gan_Chrun_result/iteration_91700.png',
#  './gan_Chrun_result/iteration_91800.png',
#  './gan_Chrun_result/iteration_91900.png',
#  './gan_Chrun_result/iteration_92000.png',
#  './gan_Chrun_result/iteration_92100.png',
#  './gan_Chrun_result/iteration_92200.png',
#  './gan_Chrun_result/iteration_92300.png',
#  './gan_Chrun_result/iteration_92400.png',
#  './gan_Chrun_result/iteration_92500.png',
#  './gan_Chrun_result/iteration_92600.png',
#  './gan_Chrun_result/iteration_92700.png',
#  './gan_Chrun_result/iteration_92800.png',
#  './gan_Chrun_result/iteration_92900.png',
#  './gan_Chrun_result/iteration_93000.png',
#  './gan_Chrun_result/iteration_93100.png',
#  './gan_Chrun_result/iteration_93200.png',
#  './gan_Chrun_result/iteration_93300.png',
#  './gan_Chrun_result/iteration_93400.png',
#  './gan_Chrun_result/iteration_93500.png',
#  './gan_Chrun_result/iteration_93600.png',
#  './gan_Chrun_result/iteration_93700.png',
#  './gan_Chrun_result/iteration_93800.png',
#  './gan_Chrun_result/iteration_93900.png',
#  './gan_Chrun_result/iteration_94000.png',
#  './gan_Chrun_result/iteration_94100.png',
#  './gan_Chrun_result/iteration_94200.png',
#  './gan_Chrun_result/iteration_94300.png',
#  './gan_Chrun_result/iteration_94400.png',
#  './gan_Chrun_result/iteration_94500.png',
#  './gan_Chrun_result/iteration_94600.png',
#  './gan_Chrun_result/iteration_94700.png',
#  './gan_Chrun_result/iteration_94800.png',
#  './gan_Chrun_result/iteration_94900.png',
#  './gan_Chrun_result/iteration_95000.png',
#  './gan_Chrun_result/iteration_95100.png',
#  './gan_Chrun_result/iteration_95200.png',
#  './gan_Chrun_result/iteration_95300.png',
#  './gan_Chrun_result/iteration_95400.png',
#  './gan_Chrun_result/iteration_95500.png',
#  './gan_Chrun_result/iteration_95600.png',
#  './gan_Chrun_result/iteration_95700.png',
#  './gan_Chrun_result/iteration_95800.png',
#  './gan_Chrun_result/iteration_95900.png',
#  './gan_Chrun_result/iteration_96000.png',
#  './gan_Chrun_result/iteration_96100.png',
#  './gan_Chrun_result/iteration_96200.png',
#  './gan_Chrun_result/iteration_96300.png',
#  './gan_Chrun_result/iteration_96400.png',
#  './gan_Chrun_result/iteration_96500.png',
#  './gan_Chrun_result/iteration_96600.png',
#  './gan_Chrun_result/iteration_96700.png',
#  './gan_Chrun_result/iteration_96800.png',
#  './gan_Chrun_result/iteration_96900.png',
#  './gan_Chrun_result/iteration_97000.png',
#  './gan_Chrun_result/iteration_97100.png',
#  './gan_Chrun_result/iteration_97200.png',
#  './gan_Chrun_result/iteration_97300.png',
#  './gan_Chrun_result/iteration_97400.png',
#  './gan_Chrun_result/iteration_97500.png',
#  './gan_Chrun_result/iteration_97600.png',
#  './gan_Chrun_result/iteration_97700.png',
#  './gan_Chrun_result/iteration_97800.png',
#  './gan_Chrun_result/iteration_97900.png',
#  './gan_Chrun_result/iteration_98000.png',
#  './gan_Chrun_result/iteration_98100.png',
#  './gan_Chrun_result/iteration_98200.png',
#  './gan_Chrun_result/iteration_98300.png',
#  './gan_Chrun_result/iteration_98400.png',
#  './gan_Chrun_result/iteration_98500.png',
#  './gan_Chrun_result/iteration_98600.png',
#  './gan_Chrun_result/iteration_98700.png',
#  './gan_Chrun_result/iteration_98800.png',
#  './gan_Chrun_result/iteration_98900.png',
#  './gan_Chrun_result/iteration_99000.png',
#  './gan_Chrun_result/iteration_99100.png',
#  './gan_Chrun_result/iteration_99200.png',
#  './gan_Chrun_result/iteration_99300.png',
#  './gan_Chrun_result/iteration_99400.png',
#  './gan_Chrun_result/iteration_99500.png',
#  './gan_Chrun_result/iteration_99600.png',
#  './gan_Chrun_result/iteration_99700.png',
#  './gan_Chrun_result/iteration_99800.png',
#  './gan_Chrun_result/iteration_99900.png']

# %% [markdown]
# * 흥미로운점은 Species 같은 경우 [-1 , 0 , 1 ] 로 minmax scaling을 한 다음에 생성을 시킴
#     * 생성물은 -1 , 1 사이에서 데이터를 생성후 Round를 하여서 사용함.
#     * 그래서 기대하는 것은 생성되는 것이 수치형으로 나오지만 -1 , 0 , 1 주변으로 모이면서 생성되는 것을 기대함.
#     * 실제 결과도 -1 , 0 , 1 주변으로 모이는 것이 확인함.
# * softmax로 생성시
#     * 문제가 생기는 것은 3클래스를 생성시키는 것을 원하는데 2가지 클래스나 1개 클래스만 생성되는 경우가 지속적으로 발생함.
#     * 흔히 논문에서는 wgan을 활용해서하면, 효과가 좋다고 이야기하고 있어서 진행중
#     * **발견!** 선형과 섞어주니까 좀 더 고르게 나오게 되는듯
#         * 더 깊게해도 잘 될까?

# %%
import os
os.system('convert -delay 30 -loop 0 %s ./gan_Chrun_result/simulation.gif' % ' '.join(imgs))
# Out:
# 0

# %%
#import os
#os.system('convert -delay 30 -loop 0 ./gan_Chrun_result/*png ./gan_Chrun_result/simulation.gif')

# %%
#x_plot
#g_plot = sess.run(G_sample)
##g_plot[:,:4] = scaler.inverse_transform(g_plot[:,:4])
#g_plot = np.concatenate((g_plot[:,:4] , np.argmax(g_plot[:,4:],1)[:,np.newaxis] ), axis = 1)

# %% [markdown]
# ```
# fig, ax = plt.subplots(3,4, figsize=(14, 10))
# axx = ax.flatten()
# num = 0
# total_dist = 0
# for i in [0,1,2] :
#     real_idx = x_plot[:,4] == i
#     fake_idx = g_plot[:,4] == i
#     dist = 0
#     for n in np.arange(4) :
#         try :
#             dist += was_dist(x_plot[real_idx,n], g_plot[fake_idx,n])
#             total_dist += dist
#         except Exception as e :
#             pass
#         sns.distplot(x_plot[real_idx,n], kde_kws ={"color": "r", "label" : "Real"} , hist_kws ={"color":"r"}, ax = axx[num])
#         sns.distplot(g_plot[fake_idx,n], kde_kws ={"color": "g", "label" : "Gene"} , hist_kws ={"color":"g"}, ax = axx[num])
#         axx[num].set_title("{} , {}".format(i , feature[n]))
#         num +=1
# plt.suptitle('Iteration %d , D_loss : %.4f , G_loss : %.4f , Dist : %.4f'%(i,dloss,gloss, total_dist) )
# plt.show()
# ```
